# %%
import pandas as pd
import numpy as np

from utils.base_set import y, y_train, y_test, X

# %%
def distribution(x: np.ndarray):
    return pd.Series(x).value_counts() / x.shape[0]

# %%
print("y\n", distribution(y), y.shape[0])
print("y_train\n", distribution(y_train), y_train.shape[0])
print("y_test\n", distribution(y_test), y_test.shape[0])
# Out:
# y
#  0    0.686
# 1    0.314
# Name: count, dtype: float64 500
# y_train
#  0    0.685969
# 1    0.314031
# Name: count, dtype: float64 449
# y_test
#  0    0.686275
# 1    0.313725
# Name: count, dtype: float64 51

# %%
pd.DataFrame(X).describe()
# Out:
#               0           1           2           3           4           5    \
# count  500.000000  500.000000  500.000000  500.000000  500.000000  500.000000
# mean    -0.009267    0.311966    0.307209    0.097470   -0.607017    0.044792
# std      0.975490    3.912558    3.767061    3.610366    3.704771    0.975781
# min     -2.752396  -12.572314  -11.683991   -9.006606  -13.404165   -2.925299
# 25%     -0.743840   -2.127998   -2.127213   -2.383809   -2.809018   -0.589888
# 50%      0.003287    0.395026    0.347173    0.117205   -0.526886    0.028390
# 75%      0.637673    3.001048    2.873274    2.515734    1.862409    0.727605
# max      2.909961   13.080686   10.988238   11.525223   12.723617    2.969670
#
#               6           7           8           9    ...         190  \
# count  500.000000  500.000000  500.000000  500.000000  ...  500.000000
# mean     0.355969    0.022677   -0.035567    0.103722  ...    0.142736
# ...
