# %%
import pandas as pd
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold
from sklearn.naive_bayes import GaussianNB
import scipy.stats as stats

from utils.base_set import X_train, y_train, seed
from utils.randomized_search import pNpUniform

# %% [markdown]
# ### Naive Bayes

# %%
model = GaussianNB()
k = 5
cv = StratifiedKFold(n_splits=k, shuffle=True, random_state=seed)
params = {
    "priors": pNpUniform(0, 1), # esto prob. es overfiteo. Deberiamos testear a lo sumo alrededor de las prob. estimadas del set
    "var_smoothing": stats.uniform(0, 1e-2)
}
n = 100
classifier_NBayes = RandomizedSearchCV(estimator=model, 
                                    param_distributions=params, 
                                    n_iter=n, 
                                    cv=cv, 
                                    scoring='roc_auc',
                                    random_state=seed)
classifier_NBayes.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=5, random_state=8241, shuffle=True),
#                    estimator=GaussianNB(), n_iter=100,
#                    param_distributions={'priors': <utils.randomized_search.pNpUniform object at 0x79fe0a7c3ee0>,
#                                         'var_smoothing': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x79fe0a81aad0>},
#                    random_state=8241, scoring='roc_auc')

# %%
best = classifier_NBayes.best_params_
auc_roc = classifier_NBayes.best_score_
print(best)
print(auc_roc)
# Out:
# {'priors': (0.46353737605279044, 0.5364626239472096), 'var_smoothing': 0.009998052376029345}
# 0.8409246677937755

# %%
columns_to_keep = ['param_priors','param_var_smoothing','mean_test_score','rank_test_score']
pd.DataFrame(classifier_NBayes.cv_results_).sort_values("rank_test_score")[columns_to_keep]
# Out:
#                                  param_priors param_var_smoothing  \
# 6   (0.46353737605279044, 0.5364626239472096)            0.009998
# 52   (0.5409363175488333, 0.4590636824511667)            0.009751
# 16   (0.2535078793981672, 0.7464921206018328)            0.009733
# 43  (0.19961932066469246, 0.8003806793353075)            0.009767
# 59   (0.5631251785254403, 0.4368748214745597)            0.009801
# ..                                        ...                 ...
# 26  (0.9331706881631359, 0.06682931183686414)            0.000324
# 37  (0.08590641854125636, 0.9140935814587436)            0.000172
# 63  (0.8831395670588915, 0.11686043294110848)            0.000132
# 14  (0.9535598966771824, 0.04644010332281756)            0.000093
# 40  (0.8527443132295204, 0.14725568677047962)            0.000059
#
#     mean_test_score  rank_test_score
# 6          0.840925                1
# 52         0.840805                2
# 16         0.840805                2
# 43         0.840805                2
# 59         0.840692                5
# ..              ...              ...
# 26         0.792758               96
# 37         0.790466               97
# 63         0.789434               98
# 14         0.787484               99
# 40         0.786338              100
#
# [100 rows x 4 columns]
